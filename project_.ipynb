# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Импорт библиотек и загрузка данных

# %%
# Данный python-скрипт имитирует запрос к БД
# Напишите ваш SQL-запрос в query и запустите данный python-скрипт для получения результата
# Перед запуском скрипта установите библиотеку duckdb

# Установка библиотеки duckdb
#!pip install duckdb duckdb-engine

# Импорт библиотек
import pandas as pd
import duckdb
import datetime as dt
import numpy as np

# %%
# Задание таблиц БД
users = pd.read_csv('users.csv')
course_users = pd.read_csv('course_users.csv')
courses = pd.read_csv('courses.csv')
course_types = pd.read_csv('course_types.csv')
lessons = pd.read_csv('lessons.csv')
subjects = pd.read_csv('subjects.csv')
cities = pd.read_csv('cities.csv')
homework_done = pd.read_csv('homework_done.csv')
homework = pd.read_csv('homework.csv')
homework_lessons = pd.read_csv('homework_lessons.csv')
user_roles = pd.read_csv('user_roles.csv')

# %%
# Задание SQL-запроса
query = """
--- выведем ID, фамилию пользователей с ролью 'student' и название города
WITH students AS (SELECT DISTINCT users.id AS user_id, users.last_name, cities.name AS city, COUNT(homework_done.id) AS homeworks  
              FROM users
              LEFT JOIN user_roles ON users.user_role_id=user_roles.id
              LEFT JOIN cities ON users.city_id=cities.id 
              JOIN homework_done ON homework_done.user_id=users.id
              WHERE user_roles.name='student'
              GROUP BY users.id, users.last_name, cities.name),
--- выведем ID, название и тип курса, число уроков в месяц на курсе, дата старта курса,
--- предмет, тип предмета для годовых курсов ОГЭ и ЕГЭ             
      year_courses AS (SELECT courses.id AS course_id, courses.name AS course_name, course_types.name AS type_course,
               courses.lessons_in_month, CAST(courses.starts_at AS DATE) AS starts_at, subjects.name AS subject_name, subjects.project
               FROM courses
               JOIN course_types ON course_types.id=courses.course_type_id
               JOIN subjects ON subjects.id=courses.subject_id
               WHERE course_types.name='Годовой')  
--- считаю, что дата создания записи в таблице "Связка курсов и пользователей" - это и есть
--- дата открытия курса ученику. А количество полных месяцев курса можно рассчитать 
--- делением числа открытых ученику уроков на число уроков в месяц на курсе               
SELECT year_courses.course_id, year_courses.course_name, year_courses.subject_name, year_courses.project,
       year_courses.type_course, year_courses.starts_at, students.user_id, students.last_name, students.city,
       course_users.active, CAST(course_users.created_at AS DATE) AS created_at,
       FLOOR(course_users.available_lessons/year_courses.lessons_in_month) AS months, students.homeworks
   
FROM students
JOIN course_users ON course_users.user_id=students.user_id
JOIN year_courses ON year_courses.course_id=course_users.course_id
                

"""

# %%
# Выполнение SQL-запроса
df = duckdb.query(query).to_df()

# %%
# Вывод результата
display(df)
# Out:
#       course_id                         course_name       subject_name  \
# 0            16               Годовой 2к25 стандарт     Обществознание
# 1            19               Годовой 2к25 стандарт            Русский
# 2            24  В погоне за пятеркой 2К25 стандарт  Математика (база)
# 3            17               Годовой 2к25 стандарт    Английский язык
# 4            16               Годовой 2к25 стандарт     Обществознание
# ...         ...                                 ...                ...
# 5391         19               Годовой 2к25 стандарт            Русский
# 5392         18               Годовой 2к25 стандарт            История
# 5393         16               Годовой 2к25 стандарт     Обществознание
# 5394         19               Годовой 2к25 стандарт            Русский
# 5395         16               Годовой 2к25 стандарт     Обществознание
#
#      project type_course  starts_at  user_id      last_name    city  active  \
# 0        ЕГЭ     Годовой 2024-09-16    10001        Markova  Самара       1
# 1        ЕГЭ     Годовой 2024-09-21    10001        Markova  Самара       1
# 2        ЕГЭ     Годовой 2024-09-17    10001        Markova  Самара       1
# 3        ЕГЭ     Годовой 2024-09-20    10003  Драгомирецкий    None       1
# 4        ЕГЭ     Годовой 2024-09-16    10006        Пушкина  Москва       1
# ...      ...         ...        ...      ...            ...     ...     ...
# 5391     ЕГЭ     Годовой 2024-09-21    33719      Новьюхова  Тюмень       1
# 5392     ЕГЭ     Годовой 2024-09-18    33719      Новьюхова  Тюмень       1
# 5393     ЕГЭ     Годовой 2024-09-16    33883        Храмова  Самара       1
# 5394     ЕГЭ     Годовой 2024-09-21    33883        Храмова  Самара       1
# 5395     ЕГЭ     Годовой 2024-09-16    33876         Фатнев  Мценск       1
#
#      created_at  months  homeworks
# 0    2024-07-25     2.0         22
# 1    2024-07-25     2.0         22
# 2    2024-09-01     2.0         22
# 3    2024-09-05     0.0          2
# 4    2024-07-25     2.0         17
# ...         ...     ...        ...
# 5391 2024-10-11     2.0         23
# 5392 2024-10-11     2.0         23
# 5393 2024-10-11     2.0         19
# 5394 2024-10-11     2.0         19
# 5395 2024-10-11     1.0          9
#
# [5396 rows x 13 columns]

# %% [markdown]
# # Предобработка данных

# %%
# посмотрим общую информацию о датасете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5396 entries, 0 to 5395
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   course_id     5396 non-null   int64
#  1   course_name   5396 non-null   object
#  2   subject_name  5396 non-null   object
#  3   project       5396 non-null   object
#  4   type_course   5396 non-null   object
#  5   starts_at     5396 non-null   datetime64[us]
#  6   user_id       5396 non-null   int64
#  7   last_name     5396 non-null   object
#  8   city          5109 non-null   object
#  9   active        5396 non-null   int64
#  10  created_at    5396 non-null   datetime64[us]
#  11  months        5383 non-null   float64
#  12  homeworks     5396 non-null   int64
# dtypes: datetime64[us](2), float64(1), int64(4), object(6)
# memory usage: 548.2+ KB

# %% [markdown]
# Проверим наличие пропущенных значений и их долю

# %%
report = df.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / df.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#               missing_values  % of total
# city                     287        0.05
# months                    13        0.00
# course_id                  0        0.00
# course_name                0        0.00
# subject_name               0        0.00
# project                    0        0.00
# type_course                0        0.00
# starts_at                  0        0.00
# user_id                    0        0.00
# last_name                  0        0.00
# active                     0        0.00
# created_at                 0        0.00
# homeworks                  0        0.00

# %% [markdown]
# Так как доля пропусков мала, удалим данные строки из датафрейма

# %%
df = df.dropna(subset = ['months', 'city'])

# %%
df.isna().sum()
# Out:
# course_id       0
# course_name     0
# subject_name    0
# project         0
# type_course     0
# starts_at       0
# user_id         0
# last_name       0
# city            0
# active          0
# created_at      0
# months          0
# homeworks       0
# dtype: int64

# %% [markdown]
# Изменим тип данных в столбце months "Число полных месяцев курсов открыто у ученика" на тип целых чисел int

# %%
df['months'] = df['months'].astype(int)

# %% [markdown]
# Проверим наличие дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим уникальные значения городов

# %%
df['city'].unique()
# Out:
# array(['Самара', 'Москва', 'Якутск', 'Анива', 'Ижевск', 'Краснодар',
#        'Хабаровск', 'Отрадный', 'Донецк', 'Холмск', 'Туймазы',
#        'Ханты-Мансийск', 'Йошкар-Ола', 'Екатеринбург', 'Ангарск', 'Арск',
#        'Пермь', 'Бабаево', 'Курган', 'Брянск', 'Ростов-на-Дону',
#        'Ессентуки', 'Куйбышев', 'Боровичи', 'Нефтеюганск', 'Коркино',
#        'Тольятти', 'Красноярск', 'Салават', 'Янаул', 'Владивосток',
#        'Новый Уренгой', 'Сочи', 'Симферополь', 'Красногорск',
#        'Набережные Челны', 'Шебекино', 'Абакан', 'Сафоново',
#        'Севастополь', 'Гатчина', 'Корсаков', 'Каспийск', 'Баксан',
#        'Барнаул', 'Псков', 'Кондопога', 'Волгоград', 'Кемерово',
#        'Улан-Удэ', 'Чапаевск', 'Новороссийск', 'Ярославль', 'Южа',
#        'Химки', 'Санкт-Петербург', 'Волгодонск', 'Ульяновск',
#        'Первоуральск', 'Нижний Тагил', 'Моршанск', 'Элиста',
#        'Прокопьевск', 'Орёл', 'Сестрорецк', 'Рязань', 'Павлово', 'Омск',
#        'Камышлов', 'Касли', 'Маркс', 'Серпухов', 'Мытищи', 'Кремёнки',
#        'Саратов', 'Тобольск', 'Новосибирск', 'Белгород', 'Воронеж',
#        'Томск', 'Раменское', 'Коломна', 'Ивантеевка', 'Щёлково',
#        'Звенигород', 'Казань', 'Михайловка', 'Тамбов', 'Электросталь',
#        'Республика Дагестанские Огни', 'Нижнекамск', 'Курганинск',
#        'Балашиха', 'Егорьевск', 'Заринск', 'Тверь', 'Обнинск',
#        'Долгопрудный', 'Кунгур', 'Новокузнецк', 'Киров', 'Владикавказ',
#        'Уфа', 'Макаров', 'Архангельск', 'Славгород', 'Калининград',
#        'Тюмень', 'Ачинск', 'Пенза', 'Коммунар', 'Пугачёв', 'Ноябрьск',
#        'Балахна', 'Нижний Новгород', 'Мензелинск', 'Усть-Джегута',
#        'Малоярославец', 'Всеволожск', 'Балтийск', 'Чебаркуль',
#        'Катав-Ивановск', 'Ухта', 'Тотьма', 'Суджа', 'Осинники',
#        'Зеленодольск', 'Советская Гавань', 'Сосновоборск', 'Ставрополь',
#        'Махачкала', 'Домодедово', 'Когалым', 'Сланцы', 'Липецк',
#        'Сарапул', 'Подольск', 'Норильск', 'Чита', 'Альметьевск',
#        'Оренбург', 'Минеральные Воды', 'Новомосковск', 'Фокино',
#        'Краснознаменск', 'Октябрьский', 'Елабуга', 'Елизово', 'Находка',
#        'Руза', 'Глазов', 'Борисоглебск', 'Белебей', 'Магадан',
#        'Новый Оскол', 'Одинцово', 'Выкса', 'Надым', 'Пушкин', 'Кумертау',
#        'Ковров', 'Ломоносов', 'Белорецк', 'Иваново', 'Суворов', 'Клин',
#        'Феодосия', 'Сургут', 'Выборг', 'Нальчик', 'Воскресенск',
#        'Апшеронск', 'Калуга', 'Черемхово', 'Иркутск', 'Каменногорск',
#        'Кореновск', 'Челябинск', 'Череповец', 'Астрахань', 'Ясный',
#        'Новочебоксарск', 'Алексин', 'Южно-Сахалинск', 'Курчатов',
#        'Уссурийск', 'Солнечногорск', 'Гагарин', 'Кохма', 'Алушта', 'Тула',
#        'Новочеркасск', 'Благовещенск', 'Коряжма', 'Белореченск', 'Канаш',
#        'Емва', 'Оха', 'Радужный', 'Володарск', 'Фрязино', 'Майкоп',
#        'Каменка', 'Серов', 'Будённовск', 'Партизанск', 'Вятские Поляны',
#        'Саранск', 'Реутов', 'Бийск', 'Кузнецк', 'Славянск-на-Кубани',
#        'Рузаевка', 'Киселёвск', 'Пыть-Ях', 'Кстово', 'Саяногорск',
#        'Смоленск', 'Рыбинск', 'Ступино', 'Бирюч', 'Искитим',
#        'Дальнегорск', 'Фролово', 'Чебоксары', 'Слободской', 'Мелеуз',
#        'Дмитров', 'Яхрома', 'Лабинск', 'Черкесск', 'Биробиджан',
#        'Пятигорск', 'Асбест', 'Жердевка', 'Кодинск', 'Куровское',
#        'Магнитогорск', 'Лобня', 'Сергиев Посад', 'Родники',
#        'Нижневартовск', 'Бугуруслан', 'Хасавюрт', 'Спасск-Дальний', 'Бор',
#        'Ногинск', 'Морозовск', 'Волжский', 'Сальск', 'Новохопёрск',
#        'Белово', 'Пушкино', 'Сортавала', 'Дорогобуж', 'Арзамас', 'Обь',
#        'Зарайск', 'Барабинск', 'Темрюк', 'Дзержинск', 'Ликино-Дулёво',
#        'Балаково', 'Лабытнанги', 'Жуковский', 'Учалы', 'Заинск',
#        'Енисейск', 'Мурманск', 'Рудня', 'Невельск', 'Ртищево', 'Сокол',
#        'Сызрань', 'Горно-Алтайск', 'Миллерово', 'Бердск', 'Лениногорск',
#        'Чистополь', 'Люберцы', 'Пионерский', 'Нурлат', 'Братск',
#        'Орехово-Зуево', 'Снежное\r', 'Муром', 'Карасук', 'Горняк',
#        'Луховицы', 'Мариинский Посад', 'Елец', 'Мирный', 'Новокуйбышевск',
#        'Нефтекамск', 'Краснокаменск', 'Ахтубинск', 'Верхотурье', 'Гай',
#        'Новодвинск', 'Озёрск', 'Вельск', 'Азов', 'Таганрог', 'Кандалакша',
#        'Южноуральск', 'Ершов', 'Луза', 'Уварово', 'Аркадак',
#        'Великий Новгород', 'Семёнов', 'Саров', 'Бирск', 'Минусинск',
#        'Железногорск', 'Орск', 'Ирбит', 'Поворино', 'Вышний Волочёк',
#        'Лангепас', 'Бугульма', 'Ишимбай', 'Каменск-Уральский',
#        'Новоалександровск', 'Каменск-Шахтинский', 'Макеевка\r',
#        'Зеленокумск', 'Петрозаводск', 'Кострома', 'Азнакаево',
#        'Кропоткин', 'Дятьково', 'Сосногорск', 'Ипатово', 'Камышин',
#        'Городец', 'Краснослободск', 'Кушва', 'Нерюнгри', 'Ревда',
#        'Адыгейск', 'Верхняя Салда', 'Чехов', 'Кызыл', 'Нижнеудинск',
#        'Волжск', 'Петропавловск-Камчатский', 'Армавир', 'Юрга',
#        'Муравленко', 'Димитровград', 'Мончегорск', 'Агидель', 'Дербент',
#        'Короча', 'Усть-Кут', 'Ейск', 'Краснотурьинск', 'Таштагол',
#        'Кинель', 'Михайловск', 'Великие Луки', 'Дальнереченск',
#        'Десногорск', 'Донецк\r', 'Салехард', 'Сысерть', 'Владимир',
#        'Анапа', 'Верхняя Пышма', 'Тарко-Сале', 'Сыктывкар', 'Калтан',
#        'Апатиты', 'Олонец', 'Северодвинск', 'Видное', 'Анжеро-Судженск',
#        'Наро-Фоминск', 'Гурьевск', 'Лукоянов', 'Павловск', 'Королёв',
#        'Плавск', 'Берёзовский', 'Полевской', 'Волхов', 'Кяхта', 'Троицк',
#        'Дмитриев', 'Старая Русса', 'Калач-на-Дону', 'Старый Оскол',
#        'Сорочинск', 'Аксай', 'Андреаполь', 'Новоаннинский', 'Щёкино',
#        'Белокуриха', 'Лиски', 'Белогорск', 'Артём', 'Мыски', 'Саянск',
#        'Бронницы', 'Сегежа', 'Белоярский', 'Заозёрск', 'Мценск', 'Рошаль',
#        'Усинск', 'Ленинск-Кузнецкий', 'Усть-Катав', 'Избербаш',
#        'Мичуринск', 'Кизляр', 'Невинномысск', 'Сватово', 'Зеленоградск',
#        'Тосно', 'Богучар', 'Комсомольск-на-Амуре', 'Горнозаводск',
#        'Курск', 'Междуреченск', 'Стрежевой', 'Цивильск', 'Стерлитамак',
#        'Кингисепп', 'Дигора', 'Гудермес', 'Электроугли', 'Алексеевка',
#        'Кисловодск', 'Дзержинский', 'Чкаловск', 'Нягань', 'Вязники',
#        'Геленджик', 'Губкин', 'Узловая', 'Хвалынск', 'Гуково', 'Туапсе',
#        'Советск', 'Змеиногорск', 'Завитинск', 'Михайлов', 'Балабаново',
#        'Лыткарино', 'Вологда', 'Истра', 'Энгельс', 'Валдай', 'Карталы',
#        'Карабулак', 'Кириши', 'Великий Устюг', 'Республика Крымск',
#        'Назарово', 'Ленск', 'Саки', 'Поронайск', 'Весьегонск', 'Можга',
#        'Зеленогорск', 'Рыбное', 'Пущино', 'Рубцовск', 'Тайшет',
#        'Советский', 'Мариинск', 'Чулым', 'Кировск', 'Уяр', 'Воркута',
#        'Евпатория', 'Мариуполь\r', 'Судак', 'Ростов', 'Болгар', 'Суздаль',
#        'Джанкой', 'Ряжск', 'Губкинский', 'Югорск', 'Копейск',
#        'Приморско-Ахтарск', 'Питкяранта', 'Полысаево', 'Буй', 'Туран',
#        'Усть-Лабинск', 'Среднеуральск', 'Жуковка', 'Ялуторовск', 'Тында',
#        'Новоуральск', 'Жигулёвск', 'Дмитровск', 'Ельня', 'Североуральск',
#        'Николаевск-на-Амуре', 'Иланский', 'Назрань', 'Черняховск',
#        'Шелехов', 'Алдан', 'Новомичуринск', 'Няндома', 'Бавлы', 'Тутаев',
#        'Изобильный', 'Комсомольск', 'Вольск', 'Новокубанск', 'Слюдянка',
#        'Колпашево', 'Лесосибирск', 'Знаменск', 'Рославль', 'Черногорск',
#        'Стародуб', 'Североморск', 'Белинский', 'Кубинка', 'Кольчугино',
#        'Урень', 'Агрыз', 'Клинцы', 'Могоча', 'Омутнинск', 'Богородицк',
#        'Лебедянь', 'Шали', 'Бердянск\r', 'Нижняя Тура', 'Шахунья', 'Ишим',
#        'Аша', 'Медногорск', 'Волоколамск', 'Шагонар', 'Шумерля', 'Талдом',
#        'Верхний Уфалей', 'Очёр', 'Обоянь', 'Яровое', 'Онега', 'Котельнич',
#        'Сосновый Бор', 'Семикаракорск', 'Менделеевск', 'Краснодон\r',
#        'Отрадное', 'Лакинск', 'Вязьма', 'Кораблино', 'Калининск',
#        'Россошь', 'Чернушка', 'Александровск', 'Миасс', 'Беслан'],
#       dtype=object)

# %%
df.describe()
# Out:
#          course_id                   starts_at       user_id       active  \
# count  5096.000000                        5096   5096.000000  5096.000000
# mean     21.151099  2024-09-19 03:03:57.362637  24725.202904     0.966248
# min      16.000000         2024-09-15 00:00:00  10001.000000     0.000000
# 25%      16.000000         2024-09-16 00:00:00  25005.750000     1.000000
# 50%      19.000000         2024-09-17 00:00:00  28304.500000     1.000000
# 75%      23.000000         2024-09-21 00:00:00  30575.500000     1.000000
# max      81.000000         2024-10-15 00:00:00  33999.000000     1.000000
# std       7.266383                         NaN   8559.682921     0.180608
#
#                        created_at       months    homeworks
# count                        5096  5096.000000  5096.000000
# mean   2024-09-17 17:25:48.508634     2.291209    21.641680
# min           2024-07-25 00:00:00     0.000000     1.000000
# 25%           2024-09-16 00:00:00     2.000000    11.000000
# 50%           2024-09-25 00:00:00     2.000000    18.000000
# 75%           2024-10-06 00:00:00     2.000000    31.000000
# max           2024-11-09 00:00:00    10.000000    82.000000
# std                           NaN     1.704687    14.444967

# %%
df[df['active'] ==0]
# Out:
#       course_id                         course_name       subject_name  \
# 8            16               Годовой 2к25 стандарт     Обществознание
# 9            24  В погоне за пятеркой 2К25 стандарт  Математика (база)
# 14           16               Годовой 2к25 стандарт     Обществознание
# 21           25               Годовой 2к25 стандарт           Биология
# 25           22               Годовой 2к25 стандарт         Литература
# ...         ...                                 ...                ...
# 5090         16               Годовой 2к25 стандарт     Обществознание
# 5119         24  В погоне за пятеркой 2К25 стандарт  Математика (база)
# 5322         42                   Годовой курс 2к25       Биология ОГЭ
# 5343         16               Годовой 2к25 стандарт     Обществознание
# 5344         22               Годовой 2к25 стандарт         Литература
#
#      project type_course  starts_at  user_id     last_name       city  active  \
# 8        ЕГЭ     Годовой 2024-09-16    10011        Ищенко      Анива       0
# 9        ЕГЭ     Годовой 2024-09-17    10011        Ищенко      Анива       0
# 14       ЕГЭ     Годовой 2024-09-16    10014       Павлова  Краснодар       0
# 21       ЕГЭ     Годовой 2024-09-17    10019      Кутылина   Отрадный       0
# 25       ЕГЭ     Годовой 2024-09-17    10024  Имамутдинова    Туймазы       0
# ...      ...         ...        ...      ...           ...        ...     ...
# 5090     ЕГЭ     Годовой 2024-09-16    33757      Савченко  Кропоткин       0
# 5119     ЕГЭ     Годовой 2024-09-17    33796      Манохина    Иркутск       0
# 5322     ОГЭ     Годовой 2024-09-30    33692      Беличева     Тюмень       0
# 5343     ЕГЭ     Годовой 2024-09-16    33900       Ощепков   Чернушка       0
# 5344     ЕГЭ     Годовой 2024-09-17    33900       Ощепков   Чернушка       0
#
#      created_at  months  homeworks
# 8    2024-07-26       0         11
# 9    2024-07-26       0         11
# 14   2024-07-26       0          4
# 21   2024-07-26       1         27
# 25   2024-07-26       0          4
# ...         ...     ...        ...
# 5090 2024-10-11       1          7
# 5119 2024-10-11       1          8
# 5322 2024-10-11       0         12
# 5343 2024-10-11       0          8
# 5344 2024-10-12       1          8
#
# [172 rows x 13 columns]

# %% [markdown]
# # Вывод:
# перед нами данные об учениках с годовых курсов ЕГЭ и ОГЭ. Проведена проверка на наличие дубликатов, пропущенных значений. В датафрейме встречаются строки с одинаковыми значениями id клиента, так как эти пользователи проходят несколько курсов одновременно. Наличие пропущенных значений в столбце months связано с отсутствием информации об открытых уроках у данного пользователя. Пропуски в столбце city связаны, скорее всего, из-за ошибки ввода данных пользователя при регистрации.
# Из 5096 строк - в 172 случаях ученики отчисленные с курса. Самая ранняя дата старта курса в датасете - 15.09.2024, максимальная - 15.10.2024.

# %% [markdown]
# # Категоризация

# %% [markdown]
# Поделим всех учеников на волны
#
#     Критерии волн:
#     • 0 волна – присоединились на курс до даты старта курса включительно
#     • 1 волна - присоединились на курс в течение 1 недели после даты старта курса включительно
#     • 2 волна - присоединились на курс в течение от 1 до 2 недель включительно после даты старта курса
#     • 3 волна - присоединились на курс в течение от 2 до 3 недель включительно после даты старта курса
#     • 4 волна - присоединились на курс в течение от 3 до 4 недель включительно после даты старта курса
#     • 5 волна - присоединились на курс от 4 недель после даты старта курса

# %%
df['delta_week'] = df['created_at'] - df['starts_at']
df['delta_week'] = df['delta_week']/np.timedelta64(1,'W')

# %%
df.head()
# Out:
#    course_id                         course_name       subject_name project  \
# 0         16               Годовой 2к25 стандарт     Обществознание     ЕГЭ
# 1         19               Годовой 2к25 стандарт            Русский     ЕГЭ
# 2         24  В погоне за пятеркой 2К25 стандарт  Математика (база)     ЕГЭ
# 4         16               Годовой 2к25 стандарт     Обществознание     ЕГЭ
# 5         16               Годовой 2к25 стандарт     Обществознание     ЕГЭ
#
#   type_course  starts_at  user_id last_name    city  active created_at  \
# 0     Годовой 2024-09-16    10001   Markova  Самара       1 2024-07-25
# 1     Годовой 2024-09-21    10001   Markova  Самара       1 2024-07-25
# 2     Годовой 2024-09-17    10001   Markova  Самара       1 2024-09-01
# 4     Годовой 2024-09-16    10006   Пушкина  Москва       1 2024-07-25
# 5     Годовой 2024-09-16    10010   Мирзоян  Якутск       1 2024-07-26
#
#    months  homeworks  delta_week
# 0       2         22   -7.571429
# 1       2         22   -8.285714
# 2       2         22   -2.285714
# 4       2         17   -7.571429
# 5       2         42   -7.428571

# %%
# Создадим функцию для категоризации данных по волнам
def category(row):
    if df['delta_week']<=0:
        return '0 волна'
    if 0<df['delta_week']<=1:
        return '1 волна'
    if 1<df['delta_week']<=2:
        return '2 волна'
    if 2<df['delta_week']<=3:
        return '3 волна' 
    if 3<df['delta_week']<=4:
        return '4 волна' 
    else:
        return '5 волна'

# %%
# добавим в датафрейм df столбец 'flow' со значениями-результатами работы функции 
df['flow'] = df.apply(category, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 # добавим в датафрейм df столбец 'flow' со значениями-результатами работы функции
# ----> 2 df['flow'] = df.apply(category, axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[29], line 3, in category(row)
#       2 def category(row):
# ----> 3     if df['delta_week']<=0:
#       4         return '0 волна'
#       5     if 0<df['delta_week']<=1:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1466, in NDFrame.__nonzero__(self)
#    1464 @final
#    1465 def __nonzero__(self) -> NoReturn:
# -> 1466     raise ValueError(
#    1467         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
